# %% [markdown]
# # iDEALParking
# ## ETL

# %% [markdown]
# ### Reading data

# %%
import pandas as pd  
import numpy as np
import math
import ast
import re

# %%
data = pd.read_csv('idealistaAPI-2018.csv')

# %% [markdown]
# ### Distance to the center
# Before cleaning data we have to delete the distance center of Idealista and compute our distance center (a matter of indexes)

# %%
def coordinates_to_distance(latitude,longitude):
    latitude_center = math.radians(41.3851001)
    longitude_center = math.radians(2.1736845)
    latitude_1 = math.radians(latitude)
    longitude_1 = math.radians(longitude)
    R_earth = 6371000.0
    inc_long = longitude_1-longitude_center
    inc_lat = latitude_1-latitude_center
    a = (math.sin(inc_lat/2))**2 + math.cos(latitude_1)*math.cos(latitude_center)*(math.sin(inc_long/2))**2
    c = 2*np.arctan2(np.sqrt(a),np.sqrt(1-a))
    d = round(R_earth*c) 
    return d
new_distance = np.zeros(len(data["latitude"]))
for i in range(0,len(data["latitude"])):
    new_distance[i] = coordinates_to_distance(data["latitude"][i],data["longitude"][i])
data["distance"] = new_distance
data = data.drop("latitude",1)
data = data.drop("longitude",1)

# %% [markdown]
# ### Only in Barcelona

# %%
data = data[data['municipality'] == 'Barcelona']
data
# Out:
#       Unnamed: 0                                   address country  \
# 0              0             calle del comte d'urgell, 234      es
# 1              1              calle de tarragona, 149 -157      es
# 2              2                    calle de Rocafort, 116      es
# 3              3                                  mallorca      es
# 4              4                      rambla de Volart, 12      es
# 6              6                             VALENCIA, 500      es
# 7              7                     avenida Diagonal, 429      es
# 8              8                      calle Sepúlveda, 104      es
# 9              9       gran via de les corts catalanes s/n      es
# 11            11               calle de Roger de Flor, 187      es
# 12            12                       calle Milanesat, 12      es
# 13            13                         paseo de Maragall      es
# 14            14                  baixada de Can Mateu, 27      es
# 15            15                     calle de Felip II, 51      es
# 16            16                          via Augusta, 312      es
# 17            17         calle de las Navas de Tolosa, 350      es
# 18            18          calle de Jordi de Sant Jordi, 31      es
# 20            20     calle de Felipe de Paz, Barcelona, 13      es
# 21            21                     calle de Pere IV, 346      es
# 22            22                calle de la Flor de Neu, 1      es
# 24            24  calle de Milà i Fontanals, Barcelona, 74      es
# 25            25           calle Villarruel y Mallorca s/n      es
# 27            27               avenida Diagonal, Barcelona      es
# 28            28             calle Padilla, Barcelona, 237      es
# 30            30                      calle de València, 3      es
# 31            31                calle de Sant Fructuós, 82      es
# 32            32                          calle Morabos, 2      es
# 33            33        plaza del Doctor Letamendi, 13 -17      es
# 36            36         calle de la Ciutat de Granada, 44      es
# 37            37        calle de la Duquessa d'Orleans, 19      es
# ...          ...                                       ...     ...
# 1076        1076                     calle de Rocafort, 64      es
# 1077        1077                    calle de Mallorca, 100      es
# 1078        1078      gran Via de les Corts Catalanes, 633      es
# 1079        1079                    calle de Mallorca, 508      es
# 1080        1080                          via augusta, 117      es
# 1081        1081               calle de santa carolina, 53      es
# 1082        1082      gran via de les corts catalanes, 391      es
# 1083        1083                     calle de mallorca, 56      es
# 1084        1084                 calle dels almogàvers, 74      es
# 1086        1086                              PADILLA, 236      es
# 1087        1087                          via Augusta, 314      es
# 1105                      NaN                garage    1682.0
# 1106                      NaN                garage    1653.0
#
#                  district  exterior         externalReference floor  \
# 0                Eixample     False        PLAZA 110 SOTANO B   NaN
# 1          Sants-Montjuïc     False         PLAZA 66 SOTANO B   NaN
# 2                Eixample     False       PLAZA MOTO SOTANO D   NaN
# 3                Eixample     False          02PLZGJEMALLORCA   NaN
# 4          Horta Guinardó     False                       NaN   NaN
# 6                Eixample     False                       NaN   NaN
# 7                Eixample     False                       NaN   NaN
# 8                Eixample     False                       NaN   NaN
# 9                Eixample     False                       NaN   NaN
# 11               Eixample     False                       NaN   NaN
# 12    Sarrià-Sant Gervasi     False                       NaN   NaN
# 13             Sant Martí     False                     04407    bj
# 14         Horta Guinardó     False                       NaN   NaN
# 15            Sant Andreu     False                       NaN   NaN
# 16    Sarrià-Sant Gervasi     False                       NaN   NaN
# 17            Sant Andreu     False                       NaN   NaN
# 18            Sant Andreu     False                       NaN   NaN
# 20              Les Corts     False                  BCN_0113   NaN
# 21             Sant Martí     False                      2608   NaN
# 22             Nou Barris     False                       NaN   NaN
# 24                 Gràcia     False                    mila 1   NaN
# 25               Eixample     False                       NaN   NaN
# 27               Eixample     False                  TFJTpkd3   NaN
# 28               Eixample     False                       NaN   NaN
# 30               Eixample     False                       NaN   NaN
# 31         Sants-Montjuïc     False                       NaN   NaN
# 32         Sants-Montjuïc     False                   MORABOS   NaN
# 33               Eixample     False                       NaN   NaN
# 36             Sant Martí     False                       NaN   NaN
# 37    Sarrià-Sant Gervasi     False                       NaN   NaN
# ...                   ...       ...                       ...   ...
# 1076             Eixample     False  PLAZA 61 SOTANO A MOTO 2   NaN
# 1077             Eixample     False          PLAZA 7 SOTANO A   NaN
# 1078             Eixample     False          PLAZA 1 SOTANO B   NaN
# 1079             Eixample     False         PLAZA 29 SOTANO D   NaN
# 1080  Sarrià-Sant Gervasi     False         PLAZA 25 SOTANO D   NaN
# 1081       Horta Guinardó     False         PLAZA 23 SOTANO C   NaN
# 1082             Eixample     False         PLAZA 13 SOTANO D   NaN
# 1083             Eixample     False         PLAZA 33 SOTANO D   NaN
# 1084           Sant Martí     False         PLAZA 35 SOTANO C   NaN
# 1086             Eixample     False       PARKING PADILLA 236   NaN
# 1087  Sarrià-Sant Gervasi     False                       NaN   NaN
# 1088  Sarrià-Sant Gervasi     False                       NaN   NaN
# 1089           Sant Martí     False                 018-014_A   NaN
# 1090           Sant Martí     False     BUENAVENTURA MUÑOZ 66   NaN
# 1091  Sarrià-Sant Gervasi     False         PLAZA 25 SOTANO E   NaN
# 1092  Sarrià-Sant Gervasi     False    PLAZA 12 Y 13 SOTANO B   NaN
# 1093            Les Corts     False              EP PAK MOS B   NaN
# 1094             Eixample     False                       NaN   NaN
# 1095             Eixample     False              PLAZA BICI 2   NaN
# 1096       Sants-Montjuïc     False         PLAZA 15 SOTANO C   NaN
# 1097  Sarrià-Sant Gervasi     False       PLAZA MOTO SOTANO B   NaN
# 1098  Sarrià-Sant Gervasi     False       PLAZA MOTO SOTANO A   NaN
# 1099             Eixample     False          PLAZA 2 SOTANO B   NaN
# 1100             Eixample     False   PLAZA 9 + TR.2 SOTANO C   NaN
# 1101          Sant Andreu     False         PLAZA 38 SOTANO C   NaN
# 1102               Gràcia     False        PLAZA 340 SOTANO C   NaN
# 1103             Eixample     False    PLAZA MOTO 37 SOTANO A   NaN
# 1104             Eixample     False         PLAZA 41 PLANTA C   NaN
# 1105             Eixample     False     PLAZA BICI 1 SOTANO A   NaN
# 1106             Eixample     False         PLAZA 89 SOTANO A   NaN
#
#                             ...                          priceByArea  \
# 0                           ...                                  NaN
# 1                           ...                                  NaN
# 2                           ...                                  NaN
# 3                           ...                                 12.0
# 4                           ...                                  8.0
# 6                           ...                                 10.0
# 7                           ...                                  NaN
# 8                           ...                                 13.0
# 9                           ...                                  NaN
# 11                          ...                                  NaN
# 12                          ...                                  NaN
# 13                          ...                                  9.0
# 14                          ...                                  NaN
# 15                          ...                                  9.0
# 16                          ...                                 10.0
# 17                          ...                                  NaN
# 18                          ...                                  9.0
# 20                          ...                                 11.0
# 21                          ...                                 10.0
# 22                          ...                                  NaN
# 24                          ...                                  NaN
# 25                          ...                                  8.0
# 27                          ...                                  9.0
# 28                          ...                                  8.0
# 30                          ...                                  NaN
# 31                          ...                                  NaN
# 32                          ...                                  NaN
# 33                          ...                                 23.0
# 36                          ...                                  NaN
# 37                          ...                                  NaN
# ...                         ...                                  ...
# 1076                        ...                                  NaN
# 1077                        ...                                  NaN
# 1078                        ...                                  NaN
# 1079                        ...                                  NaN
# 1080                        ...                                  NaN
# 1081                        ...                                  NaN
# 1082                        ...                                  NaN
# 1083                        ...                                  NaN
# 1084                        ...                                  NaN
# 1086                        ...                                  NaN
# 1087                        ...                                  NaN
# 1088                        ...                                  NaN
# 1089                        ...                                  NaN
# 1090                        ...                                  NaN
# 1091                        ...                                  NaN
# 1092                        ...                                  NaN
# 1093                        ...                                  NaN
# 1094                        ...                                  NaN
# 1095                        ...                                  NaN
# 1096                        ...                                  NaN
# 1097                        ...                                  NaN
# 1098                        ...                                  NaN
# 1099                        ...                                  NaN
# 1100                        ...                                  NaN
# 1101                        ...                                  NaN
# 1102                        ...                                  NaN
# 1103                        ...                                  NaN
# 1104                        ...                                  NaN
# 1105                        ...                                  NaN
# 1106                        ...                                  NaN
#
#       propertyCode propertyType   province  showAddress  \
# 0         38683271       garage  Barcelona         True
# 1         38681477       garage  Barcelona         True
# 2         82918245       garage  Barcelona         True
# 3         32954188       garage  Barcelona        False
# 4         82915795       garage  Barcelona         True
# 6         82914626       garage  Barcelona         True
# 7         82914148       garage  Barcelona         True
# 8         82913638       garage  Barcelona         True
# 9         33767792       garage  Barcelona         True
# 11        39586842       garage  Barcelona         True
# 12        30537514       garage  Barcelona         True
# 13        82909249       garage  Barcelona        False
# 14        82908201       garage  Barcelona         True
# 15        82907717       garage  Barcelona         True
# 16        82907169       garage  Barcelona         True
# 17        29000885       garage  Barcelona         True
# 18        82901840       garage  Barcelona         True
# 20        82906619       garage  Barcelona         True
# 21        39595735       garage  Barcelona         True
# 22        82897683       garage  Barcelona         True
# 24        82901617       garage  Barcelona         True
# 25        82881852       garage  Barcelona         True
# 27        82899246       garage  Barcelona        False
# 28        82897854       garage  Barcelona         True
# 30        82895714       garage  Barcelona         True
# 31        82895794       garage  Barcelona         True
# 32        25580502       garage  Barcelona         True
# 33        82894605       garage  Barcelona         True
# 36        28599513       garage  Barcelona         True
# 37        39955594       garage  Barcelona         True
# ...            ...          ...        ...          ...
# 1076      81277546       garage  Barcelona         True
# 1077      81277549       garage  Barcelona         True
# 1078      81277567       garage  Barcelona         True
# 1079      81277568       garage  Barcelona         True
# 1080      39183710       garage  Barcelona         True
# 1081      38968164       garage  Barcelona         True
# 1082      38683646       garage  Barcelona         True
# 1083      38968071       garage  Barcelona         True
# 1084      38680745       garage  Barcelona         True
# 1086      81198851       garage  Barcelona         True
# 1087      81165860       garage  Barcelona         True
# 1088      81165788       garage  Barcelona         True
# 1089      40539134       garage  Barcelona        False
# 1090      40468518       garage  Barcelona         True
# 1091      40405864       garage  Barcelona         True
# 1092      40405867       garage  Barcelona         True
# 1093      40207171       garage  Barcelona         True
# 1094      40164989       garage  Barcelona         True
# 1095      40132601       garage  Barcelona         True
# 1096      40119263       garage  Barcelona         True
# 1097      40065958       garage  Barcelona         True
# 1098      40065946       garage  Barcelona         True
# 1099      40065982       garage  Barcelona         True
# 1100      40065990       garage  Barcelona         True
# 1101      40066010       garage  Barcelona         True
# 1102      38684319       garage  Barcelona         True
# 1103      40039335       garage  Barcelona         True
# 1104      40039333       garage  Barcelona         True
# 1105      40039361       garage  Barcelona         True
# 1106      39763700       garage  Barcelona         True
#
#                            suggestedTexts.subtitle  \
# 0       L'Antiga Esquerra de l'Eixample, Barcelona
# 1                           Hostafrancs, Barcelona
# 2        La Nova Esquerra de l'Eixample, Barcelona
# 3        La Nova Esquerra de l'Eixample, Barcelona
# 4                           El Guinardó, Barcelona
# 6                    La Sagrada Família, Barcelona
# 7       L'Antiga Esquerra de l'Eixample, Barcelona
# 8                           Sant Antoni, Barcelona
# 9                           Sant Antoni, Barcelona
# 11               La Dreta de l'Eixample, Barcelona
# 12                      Les Tres Torres, Barcelona
# 13           El Camp de l'Arpa del Clot, Barcelona
# 14                                Horta, Barcelona
# 15                                Navas, Barcelona
# 16                               Sarrià, Barcelona
# 17                                Navas, Barcelona
# 18             El Congrés i els Indians, Barcelona
# 20           La Maternitat i Sant Ramon, Barcelona
# 21              Provençals del Poblenou, Barcelona
# 22                       La Prosperitat, Barcelona
# 24                       Vila de Gràcia, Barcelona
# 25      L'Antiga Esquerra de l'Eixample, Barcelona
# 27                        El Fort Pienc, Barcelona
# 28                   La Sagrada Família, Barcelona
# 30       La Nova Esquerra de l'Eixample, Barcelona
# 31                La Font de la Guatlla, Barcelona
# 32                La Font de la Guatlla, Barcelona
# 33      L'Antiga Esquerra de l'Eixample, Barcelona
# 36                          El Poblenou, Barcelona
# 37                               Sarrià, Barcelona
# ...                                            ...
# 1076                        Sant Antoni, Barcelona
# 1077     La Nova Esquerra de l'Eixample, Barcelona
['Plaza para coche pequeño', 'Cubierta', ' Pue...
# ...                                                 ...
# 1076                                                 []
# 1077                                                 []
# 1078                                                 []
# 1079                                       ['Cubierta']
# 1080                                                 []
# 1081                                                 []
# 1082                                       ['Cubierta']
# 1083                                       ['Cubierta']
# 1084                                       ['Cubierta']
# 1086                                                 []
# 1087  ['Plaza para coche y moto', 'Con ascensor', ' ...
# 1088  ['Plaza para coche pequeño', 'Con ascensor', '...
# 1089                                                 []
# 1090                                ['Plaza para moto']
# 1091                                       ['Cubierta']
# 1092                                                 []
# 1093                                                 []
# 1094  ['Plaza para coche grande', ' Puerta automátic...
# 1095                                       ['Cubierta']
# 1096                                                 []
# 1097                                       ['Cubierta']
# 1098                                       ['Cubierta']
# 1099                                       ['Cubierta']
# 1100                                       ['Cubierta']
# 1101                                       ['Cubierta']
# 1102                                       ['Cubierta']
# 1103                                       ['Cubierta']
# 1104                                                 []
# 1105                                       ['Cubierta']
# 1106                                       ['Cubierta']
#
# [1003 rows x 32 columns]

# %% [markdown]
# ### Dropping data

# %%
data = data.drop("detailedType.typology",1)
data = data.drop("Unnamed: 0",1)
data = data.drop("country",1)
data = data.drop("has360",1)
data = data.drop("has3DTour",1)
data = data.drop("hasVideo",1)
data = data.drop("externalReference",1)
data = data.drop("operation",1)
data = data.drop("propertyCode",1)
data = data.drop("propertyType",1)
data = data.drop("thumbnail",1)
data = data.drop("newDevelopmentFinished",1)
data = data.drop("url",1)
data = data.drop("province",1)
data = data.drop("showAddress",1)
data = data.drop("address",1)
data = data.drop("exterior",1)
data = data.drop("suggestedTexts.title",1)
data = data.drop("suggestedTexts.subtitle",1)
data = data.drop("priceByArea",1)
data = data.drop("floor",1)
data = data.drop("municipality",1)
data = data.drop("numPhotos",1)

# %%
np.unique(data['neighborhood']).shape
# Out:
# (57,)

# %% [markdown]
# ### Feature extraction

# %% [markdown]
# ##### Function for distance to center

# %%
def coordinates_to_distance(latitude,longitude):
    latitude_center = math.radians(41.3851001)
    longitude_center = math.radians(2.1736845)
    latitude_1 = math.radians(latitude)
    longitude_1 = math.radians(longitude)
    R_earth = 6371000.0
    inc_long = longitude_1-longitude_center
    inc_lat = latitude_1-latitude_center
    a = (math.sin(inc_lat/2))**2 + math.cos(latitude_1)*math.cos(latitude_center)*(math.sin(inc_long/2))**2
    c = 2*np.arctan2(np.sqrt(a),np.sqrt(1-a))
    d = R_earth*c
    return d

# %% [markdown]
# ##### Converting features

# %%
# Renaming all features
data = data.rename(columns={"detailedType.subTypology":"Type", "neighborhood":"Neighborhood", "distance":"Distance" })
data = data.rename(columns={"newDevelopment":"NewDevelopment", "hasPlan":"HasPlan" })
data = data.rename(columns={"hasLift":"HasLift", "district":"District"})

# Keeping data

data_k = data
# District
data['District'] = (data['District'].astype(str))
aux = data.copy()
#We order the number of districst correctly, instead of alphabetically
# district = np.unique(data['District'])
# for i in range(0,len(district)):
#     aux[(data['District'] == district[i])] = i+1
aux[data['District']=='Ciutat Vella'] = 1
aux[data['District']=='Eixample'] = 2
aux[data['District']=='Sants-Montjuïc'] = 3
aux[data['District']=='Les Corts'] = 4
aux[data['District']=='Sarrià-Sant Gervasi'] = 5
aux[data['District']=='Gràcia'] = 6
aux[data['District']=='Horta Guinardó'] = 7
aux[data['District']=='Nou Barris'] = 8
aux[data['District']=='Sant Andreu'] = 9
aux[data['District']=='Sant Martí'] = 10
data['District'] = aux['District']

# Neighborhood
data['Neighborhood'] = (data['Neighborhood'].astype(str))
aux = data.copy()
#We order the number of neighborhoods correctly, instead of alphabetically
# neighborhood = np.unique(data['Neighborhood'])
# for i in range(0,len(neighborhood)):
#     aux[(data['Neighborhood'] == neighborhood[i])] = i+1 
aux[data['Neighborhood']=='El Raval'] = 1
aux[data['Neighborhood']=='El Gòtic'] = 2
aux[data['Neighborhood']=='La Barceloneta'] = 3
aux[data['Neighborhood']=='Sant Pere - Santa Caterina i la Ribera'] = 4
aux[data['Neighborhood']=='El Fort Pienc'] = 5
aux[data['Neighborhood']=='La Sagrada Família'] = 6
aux[data['Neighborhood']=='La Dreta de l\'Eixample'] = 7
aux[data['Neighborhood']=='L\'Antiga Esquerra de l\'Eixample'] = 8
aux[data['Neighborhood']=='La Nova Esquerra de l\'Eixample'] = 9
aux[data['Neighborhood']=='Sant Antoni'] = 10
aux[data['Neighborhood']=='El Poble Sec - Parc de Montjuïc'] = 11
aux[data['Neighborhood']=='La Marina del Prat Vermell'] = 12
aux[data['Neighborhood']=='La Marina del Port'] = 13
aux[data['Neighborhood']=='La Font de la Guatlla'] = 14
aux[data['Neighborhood']=='Hostafrancs'] = 15
aux[data['Neighborhood']=='La Bordeta'] = 16
aux[data['Neighborhood']=='Sants - Badal'] = 17
aux[data['Neighborhood']=='Sants'] = 18 
aux[data['Neighborhood']=='Les Corts'] = 19
aux[data['Neighborhood']=='La Maternitat i Sant Ramon'] = 20
aux[data['Neighborhood']=='Pedralbes'] = 21
aux[data['Neighborhood']=='Vallvidreta, Tibidabo i les Planes'] = 22 #Wasn't in our data
aux[data['Neighborhood']=='Sarrià'] = 23
aux[data['Neighborhood']=='Les Tres Torres'] = 24
aux[data['Neighborhood']=='Sant Gervasi - La Bonanova'] = 25
aux[data['Neighborhood']=='Sant Gervasi - Galvany'] = 26
aux[data['Neighborhood']=='El Putxet i el Farró'] = 27
aux[data['Neighborhood']=='Vallcarca i els Penitents'] = 28
aux[data['Neighborhood']=='El Coll'] = 29
aux[data['Neighborhood']=='La Salut'] = 30
aux[data['Neighborhood']=='Vila de Gràcia'] = 31
aux[data['Neighborhood']=='El Camp d\'En Grassot i Gràcia Nova'] = 32
aux[data['Neighborhood']=='El Baix Guinardó'] = 33
aux[data['Neighborhood']=='Can Baró'] = 34
aux[data['Neighborhood']=='El Guinardó'] = 35
aux[data['Neighborhood']=='La Font d\'En Fargues'] = 36
aux[data['Neighborhood']=='El Carmel'] = 37
aux[data['Neighborhood']=='La Teixonera'] = 38
aux[data['Neighborhood']=='Sant Genís Dels Agudells - Montbau'] = 39 #It is together with number 40 
aux[data['Neighborhood']=='La Vall d\'Hebron - La Clota'] = 41 #It is together with number 42
aux[data['Neighborhood']=='Horta'] = 43
aux[data['Neighborhood']=='Vilapicina i la Torre Llobeta'] = 44
aux[data['Neighborhood']=='Porta'] = 45
aux[data['Neighborhood']=='Can Peguera - El Turó de la Peira'] = 46 #It is together with number 47
aux[data['Neighborhood']=='La Guineueta'] = 48
aux[data['Neighborhood']=='Les Roquetes - Canyelles'] = 49 #It is together with number 50
aux[data['Neighborhood']=='Verdun'] = 51
aux[data['Neighborhood']=='La Prosperitat'] = 52
aux[data['Neighborhood']=='La Trinitat Nova'] = 53 #Wasn't in our data
aux[data['Neighborhood']=='Ciutat Meridiana - Torre Baró - Vallbona'] = 54 #It is together with numbers 55 and 56
aux[data['Neighborhood']=='La Trinitat Vella'] = 57
aux[data['Neighborhood']=='Baró de Viver'] = 58 
aux[data['Neighborhood']=='El Bon Pastor'] = 59
aux[data['Neighborhood']=='Sant Andreu'] = 60
aux[data['Neighborhood']=='La Sagrera'] = 61
aux[data['Neighborhood']=='El Congrés i els Indians'] = 62
aux[data['Neighborhood']=='Navas'] = 63
aux[data['Neighborhood']=='El Camp de l\'Arpa del Clot'] = 64
aux[data['Neighborhood']=='El Clot'] = 65
aux[data['Neighborhood']=='El Parc i la Llacuna del Poblenou'] = 66
aux[data['Neighborhood']=='La Vila Olímpica del Poblenou'] = 67
aux[data['Neighborhood']=='El Poblenou'] = 68
aux[data['Neighborhood']=='Diagonal Mar i el Front Marítim del Poblenou'] = 69
aux[data['Neighborhood']=='El Besòs'] = 70 #It is named "El Besòs i el Maresme" in wikipedia
aux[data['Neighborhood']=='Provençals del Poblenou'] = 71
aux[data['Neighborhood']=='Sant Martí de Provençals'] = 72
aux[data['Neighborhood']=='La Verneda i la Pau'] = 73
data['Neighborhood'] = aux['Neighborhood']

# Type
data = data.dropna()
data['Type'] = (data['Type'].astype(str))
aux = data.copy()
type_ = np.unique(data['Type'])
for i in range(0,len(type_)):
    aux[(data['Type'] == type_[i])] = i+1 
data['Type'] = aux['Type']

# hasLift
dummies = [1 if x==True else  0 for x in data["HasLift"]]
data["HasLift"] = dummies

# hasPlan
dummies = [1 if x==True else  0 for x in data["HasPlan"]]
data["HasPlan"] = dummies

# newDevelopment
dummies = [1 if x==True else  0 for x in data["NewDevelopment"]]
data["NewDevelopment"] = dummies

# delete the outlier
data = data.drop([data[data['price'] == 15000.0].index[0]],axis=0)
# data[data['price'] == 15000.0].index[0]
# data = data.drop(data.index)
# data[data['price'] < 30].count()

# Reordering index
data = data.reset_index()
data = data.drop("index",1)
data
# Out:
# D:\Program Files\Anaconda\lib\site-packages\ipykernel_launcher.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Program Files\Anaconda\lib\site-packages\ipykernel_launcher.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Program Files\Anaconda\lib\site-packages\ipykernel_launcher.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Program Files\Anaconda\lib\site-packages\ipykernel_launcher.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Program Files\Anaconda\lib\site-packages\ipykernel_launcher.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
['Plaza para coche pequeño', 'Cubierta', ' Pue...
# 10    85.0  ['Plaza para coche grande', '9,5 m²', ' Puerta...
# 11   110.0  ['Plaza para coche grande', '11 m²', 'Cubierta...
# 12    35.0  ['Plaza para moto', 'Cubierta', ' Puerta autom...
# 13   100.0  ['Plaza para coche pequeño', '10,6 m²', 'Cubie...
# 14   120.0  ['Plaza para coche grande', '11 m²', 'Cubierta...
# 15   120.0  ['Plaza para coche grande', '12 m²', 'Cubierta...
# 16    70.0                                                 []
# 17   125.0  ['Plaza para coche grande', 'Cubierta', 'Con a...
# 18   140.0                                                 []
# 19   110.0                                                 []
# 20    96.0  ['Plaza para coche grande', '12 m²', 'Con asce...
# 21    95.0  ['Plaza para coche grande', 'Cubierta', 'Con a...
# 22    30.0  ['Plaza para moto', 'Cubierta', ' Puerta autom...
# 23    90.0                                                 []
# 24   130.0                                                 []
# 25    30.0                                                 []
# 26    65.0  ['Plaza para coche pequeño', 'Cubierta', ' Pue...
# 27   100.0                                                 []
# 28   130.0  ['Plaza para coche grande', 'Cubierta', ' Puer...
# 29   115.0                                                 []
# ..     ...                                                ...
# 439   30.0                                                 []
# 440   78.0  ['Plaza para coche grande', 'Cubierta', ' Puer...
# 441   30.0                                                 []
# 442   25.0  ['Plaza para moto', '8 m²', 'Con ascensor', ' ...
# 443  120.0  ['Plaza para coche pequeño', '7 m²', 'Cubierta...
# 444  130.0  ['Plaza para coche grande', '10 m²', 'Cubierta...
# 445  125.0                                                 []
# 446   90.0  ['Plaza para coche grande', '14 m²', 'Cubierta...
# 447   75.0                                                 []
# 448   95.0  ['Plaza para coche pequeño', '10 m²', 'Cubiert...
# 449   85.0  ['Plaza para coche pequeño', 'Cubierta', 'Plaz...
# 450   90.0                                                 []
# 451  120.0                                                 []
# 452   60.0  ['Plaza para moto', 'Cubierta', ' Puerta autom...
# 453  100.0                                                 []
# 454  100.0                                                 []
# 455   65.0  ['Plaza para coche pequeño', '8 m²', 'Cubierta...
# 456  100.0                                                 []
# 457  100.0               ['Plaza para coche grande', '12 m²']
# 458  100.0                                                 []
# 459   90.0                        ['Plaza para coche y moto']
# 460   80.0                                                 []
# 461   25.0  ['Plaza para moto', '30 m²', 'Cubierta', ' Pue...
# 462   90.0  ['Plaza para coche grande', '9 m²', 'Cubierta'...
# 463  100.0                                                 []
# 464  110.0  ['Plaza para coche y moto', 'Con ascensor', ' ...
# 465  100.0  ['Plaza para coche pequeño', 'Con ascensor', '...
# 466   25.0                                ['Plaza para moto']
# 467   50.0                                                 []
# 468  100.0  ['Plaza para coche grande', ' Puerta automátic...
#
# [469 rows x 9 columns]

# %% [markdown]
# ##### New features from scrapping convertion and extraction

# %%
array_new_features = data['features']
type2 = []
size = []
cover = []
elevator = []
automaticDoor = []
alarm = []
securityCam = []
security = []
pattern1 = r'^(Plazapara)'
pattern2 = r'^([1-9])'
pattern3 = r'^(Cubierta)'
pattern4 = r'^(Con)'
pattern5 = r'^(Puerta)'
pattern6 = r'^(Alarma)'
pattern7 = r'^(Cámaras)'
pattern8 = r'^(Personal)'

for i in range(0,len(array_new_features)):
    ex = ast.literal_eval(array_new_features[i])
    comp1 = 0
    comp2 = 0
    comp3 = 0
    comp4 = 0
    comp5 = 0
    comp6 = 0
    comp7 = 0
    comp8 = 0
    if not ex:
        type2.append(np.nan)
        size.append(np.nan)
        cover.append("Sincubierta")
        elevator.append("Sinascensor")
        automaticDoor.append("Sinpuertaautomáticadegaraje")
        alarm.append("Sinalarma")
        securityCam.append("Sincámaradeseguridad")
        security.append("Sinpersonaldeseguridad")
    else:
        for j in range(0,len(ex)):
            aux = ex[j].replace("m²","")
            aux = aux.replace(" ","")
            if (bool(re.match(pattern1, aux)) == True):
                type2.append(aux)
                comp1 = 1
            if (bool(re.match(pattern2, aux)) == True):
                size.append(aux)
                comp2 = 1
            if (bool(re.match(pattern3, aux)) == True):
                cover.append(aux)
                comp3 = 1
            if (bool(re.match(pattern4, aux)) == True):
                elevator.append(aux)
                comp4 = 1
            if (bool(re.match(pattern5, aux)) == True):
                automaticDoor.append(aux)
                comp5 = 1
            if (bool(re.match(pattern6, aux)) == True):
                alarm.append(aux)
                comp6 = 1
            if (bool(re.match(pattern7, aux)) == True):
                securityCam.append(aux)
                comp7 = 1
            if (bool(re.match(pattern8, aux)) == True):
                security.append(aux)
                comp8 = 1
            if j == len(ex)-1:
                if comp1 == 0:
                    type2.append(np.nan)
                if comp2 == 0:
                    size.append(np.nan)
                if comp3 == 0:
                    cover.append("Sincubierta")
                if comp4 == 0:
                    elevator.append("Sinascensor")
                if comp5 == 0:
                    automaticDoor.append("Sinpuertaautomáticadegaraje")
                if comp6 == 0:
                    alarm.append("Sinalarma")
                if comp7 == 0:
                    securityCam.append("Sincámaradeseguridad")
                if comp8 == 0:
                    security.append("Sinpersonaldeseguridad")

# %%
## Comprobation
print(len(type2))
print(len(size))
print(len(cover))
print(len(elevator))
print(len(automaticDoor))
print(len(alarm))
print(len(securityCam))
print(len(security))
# Out:
# 469
# 469
# 469
# 469
# 469
# 469
# 469
# 469

# %%
y = data["price"]
data = data.drop("price",1)
data = data.drop("features",1)

# %%
data.head()
# Out:
#    Type  Distance  District  HasLift  HasPlan  Neighborhood  NewDevelopment
# 0     4    2031.0         2        1        0             9               0
# 1     4    3468.0         7        1        0            35               0
# 2     1    2243.0         2        0        0             6               0
# 3     4    2047.0         2        1        0             8               0
# 4     2    1436.0         2        0        0            10               0

# %%
# Type2 is the same of type, so we don't need to include it. 
# HasLift is not the same of elevator in some cases so we are going to merge both of them.

dummies_cover = [1 if x=='Cubierta' else  0 for x in cover]  # 1 if there is cover, 0 otherwise
data['Cover'] = dummies_cover

dummies_elevator = [1 if x=='Conascensor' else  0 for x in elevator]  # 1 if there is lift, 0 otherwise
lift = data['HasLift'].values
merged_lift = np.array(dummies_elevator)+lift
dummies_lift = [1 if x>0 else 0 for x in merged_lift]
# data = data.drop("HasLift",1)
data['HasLift'] = dummies_lift

data['Size'] = size

dummies_autoDoor = [1 if x=='Puertaautomáticadegaraje' else  0 for x in automaticDoor]  # 1 if there is automatic door, 0 otherwise
data['AutomaticDoor'] = dummies_autoDoor

dummies_alarm = [1 if x=='Alarma' else  0 for x in alarm]  # 1 if there is alarm, 0 otherwise
data['Alarm'] = dummies_alarm

dummies_secCam = [1 if x=='Cámarasdeseguridad' else  0 for x in securityCam]  # 1 if there is security camera, 0 otherwise
data['SecurityCam'] = dummies_secCam

# 7        1   NaN              0      0            0            0
# 8        0   NaN              0      0            0            0
# 9        1   NaN              1      0            0            0
# 10       0   9,5              1      0            0            0
# 11       1    11              1      1            1            1
# 12       1   NaN              1      0            0            0
# 13       1  10,6              1      0            0            0
# 14       1    11              1      1            0            0
# 15       1    12              1      0            0            0
# 16       0   NaN              0      0            0            0
# 17       1   NaN              1      0            0            0
# 18       0   NaN              0      0            0            0
# 19       0   NaN              0      0            0            0
# 20       0    12              1      0            1            0
# 21       1   NaN              1      1            1            1
# 22       1   NaN              1      0            0            0
# 23       0   NaN              0      0            0            0
# 24       0   NaN              0      0            0            0
# 25       0   NaN              0      0            0            0
# 26       1   NaN              1      0            0            0
# 27       0   NaN              0      0            0            0
# 28       1   NaN              1      0            0            0
# 29       0   NaN              0      0            0            0
# ..     ...   ...            ...    ...          ...          ...
# 439      0   NaN              0      0            0            0
# 440      1   NaN              1      1            1            0
# 441      0   NaN              0      0            0            0
# 442      0     8              1      0            0            0
# 443      1     7              1      0            0            0
# 444      1    10              1      0            0            0
# 445      0   NaN              0      0            0            0
# 446      1    14              1      0            0            0
# 447      0   NaN              0      0            0            0
# 448      1    10              1      0            0            0
# 449      1   NaN              1      0            1            1
# 450      0   NaN              0      0            0            0
# 451      0   NaN              0      0            0            0
# 452      1   NaN              1      0            0            0
# 453      0   NaN              0      0            0            0
# 454      0   NaN              0      0            0            0
# 455      1     8              1      1            0            1
# 456      0   NaN              0      0            0            0
# 457      0    12              0      0            0            0
# 458      0   NaN              0      0            0            0
# 459      0   NaN              0      0            0            0
# 460      0   NaN              0      0            0            0
# 461      1    30              1      0            0            0
# 462      1     9              1      0            0            0
# 463      0   NaN              0      0            0            0
# 464      0   NaN              1      0            0            0
# 465      0   NaN              1      0            0            0
# 466      0   NaN              0      0            0            0
# 467      0   NaN              0      0            0            0
# 468      0   NaN              1      0            0            0
#
# [469 rows x 13 columns]

# %%
def correlation_matrix(df):
    from matplotlib import cm as cm
    import matplotlib.pyplot as plt

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Abalone Feature Correlation')
    labels=['Type','Distance','District','HasLift','HasPlan','Neighborhood','NewDevelopment']
    ax1.set_xticklabels(labels,fontsize=6)
    ax1.set_yticklabels(labels,fontsize=6)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=[.75,.8,.85,.90,.95,1])
    plt.show()

correlation_matrix(data)

# %% [markdown]
# ### Extracting X and y and saving it

# %%
X = np.array(data.values).astype(float)

## Saving it
np.save('X',X)
np.save('y',y)

# %% [markdown]
# ### Showing data

# %%
y[data["District"]=="Eixample"].mean()
district = np.unique(data['District'])
solution = []
for i in range(0,len(district)):
    aux = []
    aux.append(district[i])
    aux.append(y[(data['District'] == district[i])].mean())
    solution.append(aux)
    
# np.save(solution)
solution
# Out:
# [['Ciutat Vella', 104.52],
#  ['Eixample', 98.39276485788113],
#  ['Gràcia', 94.07035175879398],
#  ['Horta Guinardó', 85.87209302325581],
#  ['Les Corts', 99.98843930635839],
#  ['Nou Barris', 79.8225806451613],
#  ['Sant Andreu', 78.51572327044025],
#  ['Sant Martí', 151.04109589041096],
#  ['Sants-Montjuïc', 87.13304721030043],
#  ['Sarrià-Sant Gervasi', 139.0483870967742]]

# %% [markdown]
# ### First approach: mean along districts

# %%
# data

# %%
#We add the predicted value to the dataframe 
predicted = []

# data = data.drop("Predicted price by district",1)
district = np.unique(data['District'])
    
for row in data['District']:
    for i in range (0,len(district)):
        if row == district[i]:
            predicted.append(solution[i][1])

data["Predicted price by district"] = predicted



# data

# %% [markdown]
# ##### We can also add a column with the mean along neighborhoods

# %%
neighborhood = np.unique(data['Neighborhood'])
solution2 = []
for i in range(0,len(neighborhood)):
    aux = []
    aux.append(neighborhood[i])
    aux.append(y[(data['Neighborhood'] == neighborhood[i])].mean())
    solution2.append(aux)
    
# np.save(solution)
solution2
# Out:
# [['Baró de Viver', 80.0],
#  ['Can Baró', 105.0],
#  ['Can Peguera - El Turó de la Peira', 67.5],
#  ['Ciutat Meridiana - Torre Baró - Vallbona', 100.0],
#  ['Diagonal Mar i el Front Marítim del Poblenou', 78.5],
#  ['El Baix Guinardó', 98.66666666666667],
#  ['El Besòs', 5074.666666666667],
#  ['El Bon Pastor', 62.333333333333336],
#  ["El Camp d'En Grassot i Gràcia Nova", 97.8],
#  ["El Camp de l'Arpa del Clot", 87.94736842105263],
#  ['El Carmel', 85.2],
#  ['El Clot', 79.11538461538461],
#  ['El Coll', 60.916666666666664],
#  ['El Congrés i els Indians', 77.11764705882354],
#  ['El Fort Pienc', 95.0],
#  ['El Guinardó', 86.05263157894737],
#  ['El Gòtic', 108.89473684210526],
#  ['El Parc i la Llacuna del Poblenou', 78.89473684210526],
#  ['El Poble Sec - Parc de Montjuïc', 75.38095238095238],
#  ['El Poblenou', 83.26666666666667],
#  ['El Putxet i el Farró', 95.09859154929578],
#  ['El Raval', 100.52380952380952],
#  ['Horta', 66.0],
#  ['Hostafrancs', 97.50847457627118],
#  ["L'Antiga Esquerra de l'Eixample", 116.97333333333333],
#  ['La Barceloneta', 175.0],
#  ['La Bordeta', 94.33333333333333],
#  ["La Dreta de l'Eixample", 109.65697674418605],
#  ["La Font d'En Fargues", 98.2],
#  ['La Font de la Guatlla', 88.125],
#  ['La Guineueta', 63.4],
#  ['La Marina del Port', 77.57894736842105],
#  ['La Marina del Prat Vermell', 75.0],
#  ['La Maternitat i Sant Ramon', 99.52380952380952],
#  ["La Nova Esquerra de l'Eixample", 90.576],
#  ['La Prosperitat', 79.64285714285714],
#  ['La Sagrada Família', 95.32835820895522],
#  ['La Sagrera', 84.77083333333333],
#  ['La Salut', 107.14285714285714],
#  ['La Teixonera', 71.42857142857143],
#  ['La Trinitat Vella', 57.5],
#  ["La Vall d'Hebron - La Clota", 91.25],
#  ['La Verneda i la Pau', 78.75],
#  ['La Vila Olímpica del Poblenou', 84.25],
#  ['Les Corts', 96.15625],
#  ['Les Roquetes - Canyelles', 86.66666666666667],
#  ['Les Tres Torres', 123.43859649122807],
#  ['Navas', 67.14285714285714],
#  ['Pedralbes', 120.83333333333333],
#  ['Porta', 93.0],
#  ['Provençals del Poblenou', 84.05263157894737],
#  ['Sant Andreu', 87.8048780487805],
#  ['Sant Antoni', 89.65555555555555],
#  ['Sant Genís Dels Agudells - Montbau', 90.0],
#  ['Sant Gervasi - Galvany', 118.512],
#  ['Sant Gervasi - La Bonanova', 249.45333333333335],
#  ['Sant Martí de Provençals', 101.66666666666667],
#  ['Sant Pere - Santa Caterina i la Ribera', 99.83333333333333],
#  ['Sants', 85.9322033898305],
#  ['Sants - Badal', 79.89189189189189],
#  ['Sarrià', 100.3409090909091],
#  ['Vallcarca i els Penitents', 79.83720930232558],
#  ['Verdun', 94.42857142857143],
#  ['Vila de Gràcia', 109.13333333333334],
#  ['Vilapicina i la Torre Llobeta', 76.47058823529412]]

# %%
#We add the predicted value to the dataframe 
predicted = []

# data = data.drop("Predicted price by neighborhood",1)
neighborhood = np.unique(data['Neighborhood'])
    
for row in data['Neighborhood']:
    for i in range (0,len(neighborhood)):
        if row == neighborhood[i]:
            predicted.append(solution2[i][1])

data["Predicted price by neighborhood"] = predicted

data
# Out:
#                   Type  Distance             District HasLift  HasPlan  \
# 0                  NaN      2106             Eixample   False    False
# 1                  NaN      2499       Sants-Montjuïc   False    False
# 2                  NaN      1899             Eixample   False    False
# 3             sedanCar      2007             Eixample    True    False
# 4             sedanCar      3470       Horta Guinardó    True    False
# 6     carAndMotorcycle      2248             Eixample   False    False
# 7             sedanCar      2026             Eixample    True    False
# 8           compactCar      1414             Eixample   False    False
# 9             sedanCar      2246             Eixample   False    False
# 11          compactCar      1705             Eixample    True    False
# 12            sedanCar      3952  Sarrià-Sant Gervasi   False    False
# 13            sedanCar      3088           Sant Martí   False    False
# 14          compactCar      4938       Horta Guinardó   False    False
# 15            sedanCar      3973          Sant Andreu   False    False
# 16            sedanCar      4076  Sarrià-Sant Gervasi    True    False
# 17          motorcycle      3853          Sant Andreu   False    False
# 18          compactCar      4251          Sant Andreu   False     True
# 20            sedanCar      4031            Les Corts    True    False
# 21            sedanCar      3604           Sant Martí    True     True
# 22          compactCar      6646           Nou Barris   False    False
# 24            sedanCar      2215               Gràcia    True     True
# 25    carAndMotorcycle      1641             Eixample    True    False
# 27            sedanCar      1499             Eixample    True    False
# 28            sedanCar      2215             Eixample    True    False
# 30            sedanCar      2474             Eixample    True    False
# 31          motorcycle      3050       Sants-Montjuïc   False    False
# 32    carAndMotorcycle      2581       Sants-Montjuïc   False    False
# 33            sedanCar      1185             Eixample    True    False
# 36          motorcycle      2538           Sant Martí    True    False
# 37          compactCar      4661  Sarrià-Sant Gervasi   False    False
# ...                ...       ...                  ...     ...      ...
# 2811        compactCar      7255          Sant Andreu    True    False
# 2812        compactCar      2889            Les Corts   False    False
# 2814        compactCar       609             Eixample    True    False
# 2816          sedanCar      1132             Eixample    True    False
# 2817          sedanCar      1366             Eixample    True    False
# 2818        compactCar      3123           Sant Martí   False    False
# 2820        motorcycle      2677           Sant Martí   False    False
# 2821          sedanCar      4285  Sarrià-Sant Gervasi   False    False
# 2822        compactCar      3985          Sant Andreu    True    False
# 2823        compactCar      2866            Les Corts    True    False
# 2824        compactCar      3675  Sarrià-Sant Gervasi   False    False
# 2825          sedanCar       918             Eixample    True    False
# 2826          sedanCar      4741            Les Corts    True    False
# 2827          sedanCar      2701       Sants-Montjuïc    True    False
# 2828          sedanCar      3953       Sants-Montjuïc   False    False
# 2830        motorcycle      2339             Eixample    True    False
# 2832        motorcycle      4987       Horta Guinardó    True    False
# 2836        compactCar      4561       Horta Guinardó   False    False
# 2837        motorcycle      1303         Ciutat Vella   False    False
# 2839          sedanCar      2818       Sants-Montjuïc    True    False
# 2840  carAndMotorcycle      6264          Sant Andreu    True    False
# 2841          sedanCar      4427          Sant Andreu   False    False
# 2842        compactCar      3783       Sants-Montjuïc   False    False
# 2843          sedanCar      4659           Sant Martí   False    False
# 2845        compactCar      3856  Sarrià-Sant Gervasi   False    False
# 2846        compactCar      3189  Sarrià-Sant Gervasi   False    False
# 2847          sedanCar      2983           Sant Martí    True    False
# 2848          sedanCar      3194               Gràcia   False    False
# 2849          sedanCar      1977             Eixample    True    False
# 2851        compactCar      1245             Eixample    True    False
#
#                          Neighborhood  NewDevelopment  NumPhotos  price  \
# 0     L'Antiga Esquerra de l'Eixample           False          8  142.0
# 1                         Hostafrancs           False         13  150.0
# 2      La Nova Esquerra de l'Eixample           False          2   38.0
# 3      La Nova Esquerra de l'Eixample           False          9  109.0
# 4                         El Guinardó           False          1  100.0
# 6                  La Sagrada Família           False          4  130.0
# 7     L'Antiga Esquerra de l'Eixample           False          3  120.0
# 8                         Sant Antoni           False          4  100.0
# 9                         Sant Antoni           False          3   80.0
# 11             La Dreta de l'Eixample           False          3   90.0
# 12                    Les Tres Torres           False          2  100.0
# 13         El Camp de l'Arpa del Clot           False          2  105.0
# 14                              Horta           False          3   90.0
# 15                              Navas           False          4   85.0
# 16                             Sarrià           False          3  110.0
# 17                              Navas           False          2   35.0
# 18           El Congrés i els Indians           False          5  100.0
# 20         La Maternitat i Sant Ramon           False          6  120.0
# 21            Provençals del Poblenou           False         19  120.0
# 22                     La Prosperitat           False          1   70.0
# 24                     Vila de Gràcia           False          4  125.0
# 25    L'Antiga Esquerra de l'Eixample           False          2  140.0
# 27                      El Fort Pienc           False          5  110.0
# 28                 La Sagrada Família           False          5   96.0
# 30     La Nova Esquerra de l'Eixample           False          2   95.0
# 31              La Font de la Guatlla           False          5   30.0
# 32              La Font de la Guatlla           False          1   90.0
# 33    L'Antiga Esquerra de l'Eixample           False          3  130.0
# 36                        El Poblenou           False          1   30.0
# 37                             Sarrià           False          3   65.0
# ...                               ...             ...        ...    ...
# 2811                La Trinitat Vella           False          3   60.0
# 2812                        Les Corts           False          1   90.0
# 2814           La Dreta de l'Eixample           False          1  100.0
# 2816           La Dreta de l'Eixample           False          1  190.0
# 2817  L'Antiga Esquerra de l'Eixample           False          1  140.0
# 2818       El Camp de l'Arpa del Clot           False          2   90.0
# 2820                      El Poblenou           False          0   15.0
# 2821                           Sarrià           False          0  120.0
# 2822                       La Sagrera           False          0   85.0
# 2823                        Les Corts           False          0   95.0
# 2824       Sant Gervasi - La Bonanova           False          0  100.0
# 2825                      Sant Antoni           False          0  100.0
# 2826       La Maternitat i Sant Ramon           False          0   90.0
# 2827                            Sants           False          0  110.0
# 2828                    Sants - Badal           False          0   95.0
# 2830   La Nova Esquerra de l'Eixample           False          0   60.0
# 2832                            Horta           False          0   30.0
# 2836                     La Teixonera           False          0  120.0
# 2837                   La Barceloneta           False          0   50.0
# 2839                      Hostafrancs           False          0  100.0
# 2840                      Sant Andreu           False          0   90.0
# 2841                       La Sagrera           False          0   90.0
# 2842               La Marina del Port           False          0  100.0
# 2843              La Verneda i la Pau           False          0  150.0
# 2845                  Les Tres Torres           False          0   30.0
# 2846           Sant Gervasi - Galvany           False          0  100.0
# 2847       El Camp de l'Arpa del Clot           False          0   95.0
# 2848                         La Salut           False          0  100.0
# 2849               La Sagrada Família           False          0   40.0
# 2851                    El Fort Pienc           False          0   90.0
#
#       Predicted price by district  Predicted price by neighborhood
# 0                       98.392765                       116.973333
# 1                       87.133047                        97.508475
# 2                       98.392765                        90.576000
# 3                       98.392765                        90.576000
# 4                       85.872093                        86.052632
# 6                       98.392765                        95.328358
# 7                       98.392765                       116.973333
# 8                       98.392765                        89.655556
# 9                       98.392765                        89.655556
# 11                      98.392765                       109.656977
# 12                     139.048387                       123.438596
# 13                     151.041096                        87.947368
# 14                      85.872093                        66.000000
# 15                      78.515723                        67.142857
# 16                     139.048387                       100.340909
# 17                      78.515723                        67.142857
# 18                      78.515723                        77.117647
# 20                      99.988439                        99.523810
# 21                     151.041096                        84.052632
# 22                      79.822581                        79.642857
# 24                      94.070352                       109.133333
# 25                      98.392765                       116.973333
# 27                      98.392765                        95.000000
# 28                      98.392765                        95.328358
# 30                      98.392765                        90.576000
# 31                      87.133047                        88.125000
# 32                      87.133047                        88.125000
# 33                      98.392765                       116.973333
# 36                     151.041096                        83.266667
# 37                     139.048387                       100.340909
# ...                           ...                              ...
# 2811                    78.515723                        57.500000
# 2812                    99.988439                        96.156250
# 2814                    98.392765                       109.656977
# 2816                    98.392765                       109.656977
# 2817                    98.392765                       116.973333
# 2818                   151.041096                        87.947368
# 2820                   151.041096                        83.266667
# 2821                   139.048387                       100.340909
# 2822                    78.515723                        84.770833
# 2823                    99.988439                        96.156250
# 2824                   139.048387                       249.453333
# 2825                    98.392765                        89.655556
# 2826                    99.988439                        99.523810
# 2827                    87.133047                        85.932203
# 2828                    87.133047                        79.891892
# 2830                    98.392765                        90.576000
# 2832                    85.872093                        66.000000
# 2836                    85.872093                        71.428571
# 2837                   104.520000                       175.000000
# 2839                    87.133047                        97.508475
# 2840                    78.515723                        87.804878
# 2841                    78.515723                        84.770833
# 2842                    87.133047                        77.578947
# 2843                   151.041096                        78.750000
# 2845                   139.048387                       123.438596
# 2846                   139.048387                       118.512000
# 2847                   151.041096                        87.947368
# 2848                    94.070352                       107.142857
# 2849                    98.392765                        95.328358
# 2851                    98.392765                        95.000000
#
# [2352 rows x 11 columns]
